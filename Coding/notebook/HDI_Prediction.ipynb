# %% [markdown]
# # HDI Prediction
#
# This notebook is the starting point for exploring and training the HDI prediction model.

# %%
import pandas as pd

data = pd.read_csv('../hdi_dataset.csv')
data.head()
